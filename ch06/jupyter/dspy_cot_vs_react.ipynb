# %% [markdown]
# # Prompting with DSPy: Chain-of-Thought vs ReAct
#
# This notebook shows how to implement the same "math tutor" task with two
# different prompting strategies in DSPy:
#
# 1. A Chain-of-Thought (CoT) module that reasons step by step.
# 2. A ReAct agent that can call a calculator tool while reasoning.
#
# Both modules share the same DSPy signature, and they differ only in how the
# reasoning is carried out.

# %%
import os
from getpass import getpass
from openai import OpenAI

# Ask for the API key interactively if not defined as env variable
if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")
# Out:
# Enter your OpenAI API key: ··········

# %%
# %pip install dspy-ai --break-system-packages
# Out:
# Collecting dspy-ai
#   Downloading dspy_ai-3.1.3-py3-none-any.whl.metadata (285 bytes)
# Collecting dspy>=3.1.3 (from dspy-ai)
#   Downloading dspy-3.1.3-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: openai>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (2.26.0)
# Requirement already satisfied: regex>=2023.10.3 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (2025.11.3)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (3.11.7)
# Requirement already satisfied: tqdm>=4.66.1 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (4.67.3)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (2.32.4)
# Collecting optuna>=3.4.0 (from dspy>=3.1.3->dspy-ai)
#   Downloading optuna-4.7.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (2.12.3)
# Collecting litellm>=1.64.0 (from dspy>=3.1.3->dspy-ai)
#   Downloading litellm-1.82.1-py3-none-any.whl.metadata (30 kB)
# Collecting diskcache>=5.6.0 (from dspy>=3.1.3->dspy-ai)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting json-repair>=0.54.2 (from dspy>=3.1.3->dspy-ai)
#   Downloading json_repair-0.58.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (9.1.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (4.12.1)
# Collecting asyncer==0.0.8 (from dspy>=3.1.3->dspy-ai)
#   Downloading asyncer-0.0.8-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: cachetools>=5.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (6.2.6)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (3.1.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (2.0.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (3.6.0)
# Collecting gepa==0.0.26 (from gepa[dspy]==0.0.26->dspy>=3.1.3->dspy-ai)
#   Downloading gepa-0.0.26-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy>=3.1.3->dspy-ai) (3.11)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy>=3.1.3->dspy-ai) (4.15.0)
# Requirement already satisfied: aiohttp>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (3.13.3)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (8.3.1)
# Collecting fastuuid>=0.13.0 (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai)
#   Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (8.7.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (4.26.0)
# Requirement already satisfied: python-dotenv>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (1.2.2)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.12.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.22.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy>=3.1.3->dspy-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy>=3.1.3->dspy-ai) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy>=3.1.3->dspy-ai) (1.3.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.1.3->dspy-ai) (1.18.4)
# Collecting colorlog (from optuna>=3.4.0->dspy>=3.1.3->dspy-ai)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.1.3->dspy-ai) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.1.3->dspy-ai) (2.0.48)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.1.3->dspy-ai) (6.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy>=3.1.3->dspy-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy>=3.1.3->dspy-ai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy>=3.1.3->dspy-ai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy>=3.1.3->dspy-ai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy>=3.1.3->dspy-ai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy>=3.1.3->dspy-ai) (2026.2.25)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (1.23.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.4.0->dspy>=3.1.3->dspy-ai) (1.3.10)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.30.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.4.0->dspy>=3.1.3->dspy-ai) (3.3.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (1.5.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (3.25.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (1.3.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.24.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.1.2)
# Downloading dspy_ai-3.1.3-py3-none-any.whl (1.1 kB)
# Downloading dspy-3.1.3-py3-none-any.whl (312 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.4/312.4 kB 6.6 MB/s eta 0:00:00
# Downloading asyncer-0.0.8-py3-none-any.whl (9.2 kB)
# Downloading gepa-0.0.26-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.7/139.7 kB 5.2 MB/s eta 0:00:00
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.4 MB/s eta 0:00:00
# Downloading json_repair-0.58.5-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 1.4 MB/s eta 0:00:00
# Downloading litellm-1.82.1-py3-none-any.whl (15.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 73.5 MB/s eta 0:00:00
# Downloading optuna-4.7.0-py3-none-any.whl (413 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.9/413.9 kB 14.5 MB/s eta 0:00:00
# Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 13.4 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: json-repair, gepa, fastuuid, diskcache, colorlog, asyncer, optuna, litellm, dspy, dspy-ai
# Successfully installed asyncer-0.0.8 colorlog-6.10.1 diskcache-5.6.3 dspy-3.1.3 dspy-ai-3.1.3 fastuuid-0.14.0 gepa-0.0.26 json-repair-0.58.5 litellm-1.82.1 optuna-4.7.0

# %%
import os
import math
from typing import Dict
import dspy

# Make sure you have set the OPENAI_API_KEY environment variable
# before running this notebook.
lm = dspy.LM("openai/gpt-4o-mini")
dspy.configure(lm=lm)

# %%
class MathQA(dspy.Signature):
    """
    Solve short math word problems and return the final numeric answer.

    The model receives a natural language question and should output only
    the final numeric answer as text (no units or extra commentary).
    """

    question: str = dspy.InputField(
        desc="a short math word problem stated in natural language"
    )
    answer: str = dspy.OutputField(
        desc="the final numeric answer only, without units or extra text"
    )

# %% [markdown]
# ## Chain-of-Thought module
#
# `dspy.ChainOfThought` implements a classic "think step by step" prompting
# strategy. It augments the signature with an additional field that stores
# the reasoning trace, and then predicts both the reasoning and the final
# answer.
#
# We will instantiate a Chain-of-Thought solver for the `MathQA` task and
# query it with a simple word problem.

# %%
cot_math_solver = dspy.ChainOfThought(MathQA)

example_question = """
A train travels 80 kilometers in 1 hour and 20 minutes.
What is its average speed in kilometers per hour?
"""

cot_prediction = cot_math_solver(question=example_question)

print("=== Chain-of-Thought prediction ===")
print("Question:")
print(example_question.strip())
print("\nReasoning:")
print(cot_prediction.reasoning)
print("\nAnswer:")
print(cot_prediction.answer)
# Out:
# === Chain-of-Thought prediction ===
# Question:
# A train travels 80 kilometers in 1 hour and 20 minutes.
# What is its average speed in kilometers per hour?
#
# Reasoning:
# To find the average speed, we need to divide the total distance traveled by the total time taken. The train travels 80 kilometers in 1 hour and 20 minutes. First, we convert the time into hours: 1 hour and 20 minutes is equivalent to 1 + (20/60) = 1 + 1/3 = 1.333 hours. Now, we calculate the average speed: average speed = distance / time = 80 kilometers / 1.333 hours ≈ 60 kilometers per hour.
#
# Answer:
# 60

# %% [markdown]
# ## ReAct agent with a calculator tool
#
# `dspy.ReAct` implements the ReAct (Reasoning + Acting) pattern. The model
# can interleave free-form reasoning with calls to external tools until it
# decides to finish with an answer.
#
# Here, we define a simple calculator tool and pass it to `dspy.ReAct`. The
# agent can choose to call this tool to perform exact arithmetic while it
# reasons about a word problem.

# %%
def safe_calculator(expression: str) -> str:
    """
    Evaluate a basic arithmetic expression involving +, -, *, /, and parentheses.

    The tool returns the numeric result as a string.
    It is intended for simple math expressions extracted from short word problems.
    """

    allowed_names: Dict[str, object] = {
        "sqrt": math.sqrt,
        "ceil": math.ceil,
        "floor": math.floor,
    }

    try:
        result = eval(expression, {"__builtins__": {}}, allowed_names)
    except Exception as exc:
        return f"Error evaluating expression: {exc}"

    return str(result)

# %%
react_math_agent = dspy.ReAct(
    signature=MathQA,
    tools=[safe_calculator],
    max_iters=5,
)

react_question = """
A book costs 18 euros before tax. It is discounted by 15%,
and then you buy 3 copies at the discounted price.
What is the total amount you pay (ignoring tax), in euros?
"""

react_prediction = react_math_agent(question=react_question)

print("=== ReAct prediction ===")
print("Question:")
print(react_question.strip())
print("\nAnswer:")
print(react_prediction.answer)

print("\n=== ReAct trajectory ===")
print(react_prediction.trajectory)
# Out:
# === ReAct prediction ===
# Question:
# A book costs 18 euros before tax. It is discounted by 15%,
# and then you buy 3 copies at the discounted price.
# What is the total amount you pay (ignoring tax), in euros?
#
# Answer:
# 45.9
#
# === ReAct trajectory ===
# {'thought_0': 'I need to calculate the price of one book after applying the 15% discount. Then I will multiply that discounted price by 3 to find the total cost for 3 copies.', 'tool_name_0': 'safe_calculator', 'tool_args_0': {'expression': '18 * 0.85 * 3'}, 'observation_0': '45.9', 'thought_1': 'I have calculated the total cost for the three copies of the book after the discount, which is 45.9 euros. Since I now have my final answer, I can finish the task.', 'tool_name_1': 'finish', 'tool_args_1': {}, 'observation_1': 'Completed.'}

# %% [markdown]
# ## Inspecting and comparing behaviors
#
# At this point, you have two implementations of the same `MathQA` task:
#
# * `cot_math_solver`: a `ChainOfThought` module that keeps all reasoning
#   inside the language model and exposes the reasoning via the
#   `prediction.reasoning` field.
# * `react_math_agent`: a `ReAct` agent that can call `safe_calculator`
#   while reasoning. Its `prediction.trajectory` shows the sequence of
#   thoughts, tool calls, and observations.
#
# Try editing the questions and re-running the cells to see how the two
# strategies behave differently. In a larger system, you could swap
# `ChainOfThought` for `ReAct` (or vice versa) without changing the rest of
# your application, because both implement the same `MathQA` signature.
